# %% [markdown]
# ## Classifieur simple x --> z
# (256 x 256)
# Tests avec bruit et information de position : u, x --> z
#
# Sans bruit, le clasifieur produit un taux de reconnaissance acceptable sans inforlmation deposition
# Avec bruit :
#  - 0.01 : legere degradaion du taux de reconnaissance
#  - 0.03 : forte degradation du taux de reconnaisance
#  - 0.1 : pas d'apprentissage
#
# L'information deposition ne semble pas ici utile au classifieur

# %%
# %matplotlib inline

# %%
from Where_PG_classif import init
args = init(verbose=1, epochs=10)
print('Parameters=', args)
# Out:
# Parameters= {'epochs': 10, 'size': 256, 'dimension': 25, 'valid_size': 0.2, 'num_processes': 1, 'log_interval': 10, 'verbose': 1, 'mean': 0.0, 'batch_size': 50, 'seed': 42, 'test_batch_size': 1, 'std': 1.0, 'lr': 0.001, 'no_cuda': True, 'momentum': 0.48}

# %%
import numpy as np
import torch

# %%
import easydict

# %% [markdown]
# ## Réseau de neurones

# %% [markdown]
# ### Lancer l'apprentissage ou charger les données

# %%
path = '2018-07-20_classification_PGLoss_classif_256.pt'

# %%
# !ls -l {path}
# !rm {path}
# Out:
# ls: impossible d'accéder à '2018-07-20_classification_PGLoss_classif_256.pt': Aucun fichier ou dossier de ce type
# rm: impossible de supprimer '2018-07-20_classification_PGLoss_classif_256.pt': Aucun fichier ou dossier de ce type

# %%
from Where_PG_classif import ML
ml = ML(args)
# Out:
# cuda? False

# %%
ml.dataset.show()
# Out:
# (<matplotlib.figure.Figure at 0x7feecd00a470>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fee92db1438>)

# %%
print(ml.model)
# Out:
# Net(
#   (conv1): Conv2d(1, 16, kernel_size=(4, 4), stride=(4, 4), bias=False)
#   (conv2): Conv2d(16, 64, kernel_size=(4, 4), stride=(4, 4), bias=False)
#   (conv3): Conv2d(64, 256, kernel_size=(4, 4), stride=(4, 4), bias=False)
#   (conv4): Conv2d(256, 1024, kernel_size=(4, 4), stride=(4, 4), bias=False)
#   (fc_pos_1): Linear(in_features=2, out_features=32, bias=False)
#   (fc_pos_2): Linear(in_features=32, out_features=1024, bias=False)
#   (fc_label_out): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
ml.args.epochs = 1000

# %%
#ml.model.fc_logvar.weight

# %%
#ml.model.fc_logvar.weight

# %%
#ml.model.fc_mu.weight

# %%
#ml.model.fc_mu.weight

# %%
ml.train(None)
# Out:
# Train Epoch
# 	Train Epoch: 1 [0/60000 (0%)]	CLoss: 2.302579	PG: 0.000000	KL: 0.000000	 Acc:0.120000
# 	Train Epoch: 1 [500/60000 (1%)]	CLoss: 2.303449	PG: 0.000000	KL: 0.000000	 Acc:0.100000
# 	Train Epoch: 1 [1000/60000 (2%)]	CLoss: 2.301193	PG: 0.000000	KL: 0.000000	 Acc:0.120000
# 	Train Epoch: 1 [1500/60000 (2%)]	CLoss: 2.313378	PG: 0.000000	KL: 0.000000	 Acc:0.080000
# 	Train Epoch: 1 [2000/60000 (3%)]	CLoss: 2.286615	PG: 0.000000	KL: 0.000000	 Acc:0.060000
# 	Train Epoch: 1 [2500/60000 (4%)]	CLoss: 2.253253	PG: 0.000000	KL: 0.000000	 Acc:0.080000
# 	Train Epoch: 1 [3000/60000 (5%)]	CLoss: 2.274303	PG: 0.000000	KL: 0.000000	 Acc:0.120000
# 	Train Epoch: 1 [3500/60000 (6%)]	CLoss: 2.290661	PG: 0.000000	KL: 0.000000	 Acc:0.100000
# 	Train Epoch: 1 [4000/60000 (7%)]	CLoss: 2.289655	PG: 0.000000	KL: 0.000000	 Acc:0.040000
# 	Train Epoch: 1 [4500/60000 (8%)]	CLoss: 2.266619	PG: 0.000000	KL: 0.000000	 Acc:0.040000
# 	Train Epoch: 1 [5000/60000 (8%)]	CLoss: 2.300780	PG: 0.000000	KL: 0.000000	 Acc:0.040000
# 	Train Epoch: 1 [5500/60000 (9%)]	CLoss: 2.295824	PG: 0.000000	KL: 0.000000	 Acc:0.120000
# 	Train Epoch: 1 [6000/60000 (10%)]	CLoss: 2.293502	PG: 0.000000	KL: 0.000000	 Acc:0.040000
# 	Train Epoch: 1 [6500/60000 (11%)]	CLoss: 2.272356	PG: 0.000000	KL: 0.000000	 Acc:0.120000
# 	Train Epoch: 1 [7000/60000 (12%)]	CLoss: 2.309108	PG: 0.000000	KL: 0.000000	 Acc:0.120000
# 	Train Epoch: 1 [7500/60000 (12%)]	CLoss: 2.279361	PG: 0.000000	KL: 0.000000	 Acc:0.120000
# 	Train Epoch: 1 [8000/60000 (13%)]	CLoss: 2.276412	PG: 0.000000	KL: 0.000000	 Acc:0.140000
# 	Train Epoch: 1 [8500/60000 (14%)]	CLoss: 2.276666	PG: 0.000000	KL: 0.000000	 Acc:0.100000
# 	Train Epoch: 1 [9000/60000 (15%)]	CLoss: 2.264162	PG: 0.000000	KL: 0.000000	 Acc:0.140000
# 	Train Epoch: 1 [9500/60000 (16%)]	CLoss: 2.284903	PG: 0.000000	KL: 0.000000	 Acc:0.040000
# 	Train Epoch: 1 [10000/60000 (17%)]	CLoss: 2.234971	PG: 0.000000	KL: 0.000000	 Acc:0.120000
# 	Train Epoch: 1 [10500/60000 (18%)]	CLoss: 2.258034	PG: 0.000000	KL: 0.000000	 Acc:0.080000
# 	Train Epoch: 1 [11000/60000 (18%)]	CLoss: 2.242562	PG: 0.000000	KL: 0.000000	 Acc:0.240000
# 	Train Epoch: 1 [11500/60000 (19%)]	CLoss: 2.216590	PG: 0.000000	KL: 0.000000	 Acc:0.160000
# 	Train Epoch: 1 [12000/60000 (20%)]	CLoss: 2.207630	PG: 0.000000	KL: 0.000000	 Acc:0.260000
# 	Train Epoch: 1 [12500/60000 (21%)]	CLoss: 2.204719	PG: 0.000000	KL: 0.000000	 Acc:0.220000
# 	Train Epoch: 1 [13000/60000 (22%)]	CLoss: 2.306045	PG: 0.000000	KL: 0.000000	 Acc:0.060000
# 	Train Epoch: 1 [13500/60000 (22%)]	CLoss: 2.229848	PG: 0.000000	KL: 0.000000	 Acc:0.140000
# 	Train Epoch: 1 [14000/60000 (23%)]	CLoss: 2.162429	PG: 0.000000	KL: 0.000000	 Acc:0.160000
# 	Train Epoch: 1 [14500/60000 (24%)]	CLoss: 2.172265	PG: 0.000000	KL: 0.000000	 Acc:0.140000
# 	Train Epoch: 1 [15000/60000 (25%)]	CLoss: 2.163217	PG: 0.000000	KL: 0.000000	 Acc:0.220000
# 	Train Epoch: 1 [15500/60000 (26%)]	CLoss: 2.068723	PG: 0.000000	KL: 0.000000	 Acc:0.260000
# 	Train Epoch: 1 [16000/60000 (27%)]	CLoss: 2.189279	PG: 0.000000	KL: 0.000000	 Acc:0.140000
# 	Train Epoch: 1 [16500/60000 (28%)]	CLoss: 2.218383	PG: 0.000000	KL: 0.000000	 Acc:0.100000
# 	Train Epoch: 1 [17000/60000 (28%)]	CLoss: 2.285460	PG: 0.000000	KL: 0.000000	 Acc:0.180000
# 	Train Epoch: 1 [17500/60000 (29%)]	CLoss: 2.098161	PG: 0.000000	KL: 0.000000	 Acc:0.280000
# 	Train Epoch: 1 [18000/60000 (30%)]	CLoss: 2.013096	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [18500/60000 (31%)]	CLoss: 2.092502	PG: 0.000000	KL: 0.000000	 Acc:0.160000
# 	Train Epoch: 1 [19000/60000 (32%)]	CLoss: 2.082303	PG: 0.000000	KL: 0.000000	 Acc:0.220000
# 	Train Epoch: 1 [19500/60000 (32%)]	CLoss: 2.082081	PG: 0.000000	KL: 0.000000	 Acc:0.160000
# 	Train Epoch: 1 [20000/60000 (33%)]	CLoss: 1.872028	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [20500/60000 (34%)]	CLoss: 2.127534	PG: 0.000000	KL: 0.000000	 Acc:0.180000
# 	Train Epoch: 1 [21000/60000 (35%)]	CLoss: 2.012524	PG: 0.000000	KL: 0.000000	 Acc:0.180000
# 	Train Epoch: 1 [21500/60000 (36%)]	CLoss: 2.008288	PG: 0.000000	KL: 0.000000	 Acc:0.220000
# 	Train Epoch: 1 [22000/60000 (37%)]	CLoss: 1.963167	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [22500/60000 (38%)]	CLoss: 2.090627	PG: 0.000000	KL: 0.000000	 Acc:0.100000
# 	Train Epoch: 1 [23000/60000 (38%)]	CLoss: 1.937039	PG: 0.000000	KL: 0.000000	 Acc:0.360000
# 	Train Epoch: 1 [23500/60000 (39%)]	CLoss: 1.835598	PG: 0.000000	KL: 0.000000	 Acc:0.400000
# 	Train Epoch: 1 [24000/60000 (40%)]	CLoss: 1.923244	PG: 0.000000	KL: 0.000000	 Acc:0.220000
# 	Train Epoch: 1 [24500/60000 (41%)]	CLoss: 2.002136	PG: 0.000000	KL: 0.000000	 Acc:0.240000
# 	Train Epoch: 1 [25000/60000 (42%)]	CLoss: 1.609689	PG: 0.000000	KL: 0.000000	 Acc:0.380000
# 	Train Epoch: 1 [25500/60000 (42%)]	CLoss: 1.900539	PG: 0.000000	KL: 0.000000	 Acc:0.240000
# 	Train Epoch: 1 [26000/60000 (43%)]	CLoss: 1.828573	PG: 0.000000	KL: 0.000000	 Acc:0.260000
# 	Train Epoch: 1 [26500/60000 (44%)]	CLoss: 1.785427	PG: 0.000000	KL: 0.000000	 Acc:0.260000
# 	Train Epoch: 1 [27000/60000 (45%)]	CLoss: 2.008136	PG: 0.000000	KL: 0.000000	 Acc:0.200000
# 	Train Epoch: 1 [27500/60000 (46%)]	CLoss: 1.897108	PG: 0.000000	KL: 0.000000	 Acc:0.200000
# 	Train Epoch: 1 [28000/60000 (47%)]	CLoss: 1.831336	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [28500/60000 (48%)]	CLoss: 1.844170	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [29000/60000 (48%)]	CLoss: 1.844687	PG: 0.000000	KL: 0.000000	 Acc:0.260000
# 	Train Epoch: 1 [29500/60000 (49%)]	CLoss: 1.778742	PG: 0.000000	KL: 0.000000	 Acc:0.280000
# 	Train Epoch: 1 [30000/60000 (50%)]	CLoss: 1.988333	PG: 0.000000	KL: 0.000000	 Acc:0.200000
# 	Train Epoch: 1 [30500/60000 (51%)]	CLoss: 1.848742	PG: 0.000000	KL: 0.000000	 Acc:0.240000
# 	Train Epoch: 1 [31000/60000 (52%)]	CLoss: 1.772730	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [31500/60000 (52%)]	CLoss: 1.935675	PG: 0.000000	KL: 0.000000	 Acc:0.260000
# 	Train Epoch: 1 [32000/60000 (53%)]	CLoss: 2.123216	PG: 0.000000	KL: 0.000000	 Acc:0.180000
# 	Train Epoch: 1 [32500/60000 (54%)]	CLoss: 1.832032	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [33000/60000 (55%)]	CLoss: 1.711475	PG: 0.000000	KL: 0.000000	 Acc:0.280000
# 	Train Epoch: 1 [33500/60000 (56%)]	CLoss: 1.807345	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [34000/60000 (57%)]	CLoss: 1.892699	PG: 0.000000	KL: 0.000000	 Acc:0.240000
# 	Train Epoch: 1 [34500/60000 (58%)]	CLoss: 2.023053	PG: 0.000000	KL: 0.000000	 Acc:0.220000
# 	Train Epoch: 1 [35000/60000 (58%)]	CLoss: 1.794793	PG: 0.000000	KL: 0.000000	 Acc:0.340000
# 	Train Epoch: 1 [35500/60000 (59%)]	CLoss: 1.687159	PG: 0.000000	KL: 0.000000	 Acc:0.360000
# 	Train Epoch: 1 [36000/60000 (60%)]	CLoss: 1.654678	PG: 0.000000	KL: 0.000000	 Acc:0.400000
# 	Train Epoch: 1 [36500/60000 (61%)]	CLoss: 1.783526	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [37000/60000 (62%)]	CLoss: 1.833291	PG: 0.000000	KL: 0.000000	 Acc:0.180000
# 	Train Epoch: 1 [37500/60000 (62%)]	CLoss: 1.752613	PG: 0.000000	KL: 0.000000	 Acc:0.280000
# 	Train Epoch: 1 [38000/60000 (63%)]	CLoss: 1.773858	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [38500/60000 (64%)]	CLoss: 1.897590	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [39000/60000 (65%)]	CLoss: 1.848386	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [39500/60000 (66%)]	CLoss: 1.640712	PG: 0.000000	KL: 0.000000	 Acc:0.400000
# 	Train Epoch: 1 [40000/60000 (67%)]	CLoss: 1.737191	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [40500/60000 (68%)]	CLoss: 1.791273	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [41000/60000 (68%)]	CLoss: 1.830978	PG: 0.000000	KL: 0.000000	 Acc:0.260000
# 	Train Epoch: 1 [41500/60000 (69%)]	CLoss: 1.755731	PG: 0.000000	KL: 0.000000	 Acc:0.400000
# 	Train Epoch: 1 [42000/60000 (70%)]	CLoss: 1.503298	PG: 0.000000	KL: 0.000000	 Acc:0.420000
# 	Train Epoch: 1 [42500/60000 (71%)]	CLoss: 1.872853	PG: 0.000000	KL: 0.000000	 Acc:0.240000
# 	Train Epoch: 1 [43000/60000 (72%)]	CLoss: 1.724075	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [43500/60000 (72%)]	CLoss: 1.722068	PG: 0.000000	KL: 0.000000	 Acc:0.280000
# 	Train Epoch: 1 [44000/60000 (73%)]	CLoss: 1.488190	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [44500/60000 (74%)]	CLoss: 1.528269	PG: 0.000000	KL: 0.000000	 Acc:0.440000
# 	Train Epoch: 1 [45000/60000 (75%)]	CLoss: 1.686330	PG: 0.000000	KL: 0.000000	 Acc:0.280000
# 	Train Epoch: 1 [45500/60000 (76%)]	CLoss: 1.684641	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [46000/60000 (77%)]	CLoss: 1.606073	PG: 0.000000	KL: 0.000000	 Acc:0.380000
# 	Train Epoch: 1 [46500/60000 (78%)]	CLoss: 1.706830	PG: 0.000000	KL: 0.000000	 Acc:0.340000
# 	Train Epoch: 1 [47000/60000 (78%)]	CLoss: 1.567601	PG: 0.000000	KL: 0.000000	 Acc:0.500000
# 	Train Epoch: 1 [47500/60000 (79%)]	CLoss: 1.536294	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 1 [48000/60000 (80%)]	CLoss: 1.533957	PG: 0.000000	KL: 0.000000	 Acc:0.280000
# 	Train Epoch: 1 [48500/60000 (81%)]	CLoss: 1.529545	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [49000/60000 (82%)]	CLoss: 1.338608	PG: 0.000000	KL: 0.000000	 Acc:0.480000
# 	Train Epoch: 1 [49500/60000 (82%)]	CLoss: 1.656962	PG: 0.000000	KL: 0.000000	 Acc:0.220000
# 	Train Epoch: 1 [50000/60000 (83%)]	CLoss: 1.540197	PG: 0.000000	KL: 0.000000	 Acc:0.420000
# 	Train Epoch: 1 [50500/60000 (84%)]	CLoss: 1.760163	PG: 0.000000	KL: 0.000000	 Acc:0.380000
# 	Train Epoch: 1 [51000/60000 (85%)]	CLoss: 1.771213	PG: 0.000000	KL: 0.000000	 Acc:0.380000
# 	Train Epoch: 1 [51500/60000 (86%)]	CLoss: 1.572090	PG: 0.000000	KL: 0.000000	 Acc:0.360000
# 	Train Epoch: 1 [52000/60000 (87%)]	CLoss: 1.538353	PG: 0.000000	KL: 0.000000	 Acc:0.320000
# 	Train Epoch: 1 [52500/60000 (88%)]	CLoss: 1.269094	PG: 0.000000	KL: 0.000000	 Acc:0.440000
# 	Train Epoch: 1 [53000/60000 (88%)]	CLoss: 1.229707	PG: 0.000000	KL: 0.000000	 Acc:0.520000
# 	Train Epoch: 1 [53500/60000 (89%)]	CLoss: 1.685678	PG: 0.000000	KL: 0.000000	 Acc:0.340000
# 	Train Epoch: 1 [54000/60000 (90%)]	CLoss: 1.565850	PG: 0.000000	KL: 0.000000	 Acc:0.380000
# 	Train Epoch: 1 [54500/60000 (91%)]	CLoss: 1.420798	PG: 0.000000	KL: 0.000000	 Acc:0.460000
# 	Train Epoch: 1 [55000/60000 (92%)]	CLoss: 1.482915	PG: 0.000000	KL: 0.000000	 Acc:0.420000
# 	Train Epoch: 1 [55500/60000 (92%)]	CLoss: 1.346400	PG: 0.000000	KL: 0.000000	 Acc:0.500000
# 	Train Epoch: 1 [56000/60000 (93%)]	CLoss: 1.590524	PG: 0.000000	KL: 0.000000	 Acc:0.380000
# 	Train Epoch: 1 [56500/60000 (94%)]	CLoss: 1.378469	PG: 0.000000	KL: 0.000000	 Acc:0.460000
# 	Train Epoch: 1 [57000/60000 (95%)]	CLoss: 1.388222	PG: 0.000000	KL: 0.000000	 Acc:0.400000
# 	Train Epoch: 1 [57500/60000 (96%)]	CLoss: 1.304466	PG: 0.000000	KL: 0.000000	 Acc:0.500000
# 	Train Epoch: 1 [58000/60000 (97%)]	CLoss: 1.582014	PG: 0.000000	KL: 0.000000	 Acc:0.400000
# 	Train Epoch: 1 [58500/60000 (98%)]	CLoss: 1.432360	PG: 0.000000	KL: 0.000000	 Acc:0.480000
# 	Train Epoch: 1 [59000/60000 (98%)]	CLoss: 1.376121	PG: 0.000000	KL: 0.000000	 Acc:0.500000
# 	Train Epoch: 1 [59500/60000 (99%)]	CLoss: 1.530873	PG: 0.000000	KL: 0.000000	 Acc:0.300000
# 	Train Epoch: 2 [0/60000 (0%)]	CLoss: 1.558034	PG: 0.000000	KL: 0.000000	 Acc:0.400000
# 	Train Epoch: 2 [500/60000 (1%)]	CLoss: 1.749608	PG: 0.000000	KL: 0.000000	 Acc:0.420000
# 	Train Epoch: 2 [1000/60000 (2%)]	CLoss: 1.309768	PG: 0.000000	KL: 0.000000	 Acc:0.420000
# 	Train Epoch: 2 [1500/60000 (2%)]	CLoss: 1.398285	PG: 0.000000	KL: 0.000000	 Acc:0.500000
# 	Train Epoch: 2 [2000/60000 (3%)]	CLoss: 1.213898	PG: 0.000000	KL: 0.000000	 Acc:0.540000
# 	Train Epoch: 2 [2500/60000 (4%)]	CLoss: 1.235887	PG: 0.000000	KL: 0.000000	 Acc:0.520000
# 	Train Epoch: 2 [3000/60000 (5%)]	CLoss: 1.321245	PG: 0.000000	KL: 0.000000	 Acc:0.420000
# 	Train Epoch: 2 [3500/60000 (6%)]	CLoss: 1.771697	PG: 0.000000	KL: 0.000000	 Acc:0.360000
# Process Process-3:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/torch/utils/data/dataloader.py", line 52, in _worker_loop
#     r = index_queue.get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-2cb754919db9> in <module>()
# ----> 1 ml.train(None)
#
# ~/Recherche/stages/Malek Bouguerra 2018/Active-Vision-Probabilistic-Model/Where_PG_classif.py in train(self, path)
#     264         else:
#     265             for epoch in tqdm(range(1, self.args.epochs + 1), desc='Train Epoch' if self.args.verbose else None):
# --> 266                 self.train_epoch(epoch, rank=0)
#     267
#     268     def train_epoch(self, epoch, rank=0):
#
# ~/Recherche/stages/Malek Bouguerra 2018/Active-Vision-Probabilistic-Model/Where_PG_classif.py in train_epoch(self, epoch, rank)
#     295             # Predict classes using images from the train set
#     296             #mu_output, logvar_output, u_output,
# --> 297             z_hat_logit_output = self.model(data_full, label_full, pos_full)
#     298
#     299             # print(output.shape, acc_full.shape)
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/Recherche/stages/Malek Bouguerra 2018/Active-Vision-Probabilistic-Model/Where_PG_classif.py in forward(self, x, z, u_in)
#     143         x = F.relu(self.conv2(x))
#     144         x = F.relu(self.conv3(x))
# --> 145         x = self.conv4(x)
#     146         #x = self.conv3(x)
#     147         n = self.num_flat_features(x)
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.5/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# KeyboardInterrupt:

# %%
if True:
    torch.save(ml.model.state_dict(), path) #save the neural network state

# %% [markdown]
# ### Lancer l'évaluation

# %%
# %matplotlib inline
import torch

from Where_PG_classif import couples_gen
from scipy.stats import multivariate_normal

import numpy as np
import torch.nn.functional as F


N_test = 10

for _ in range(N_test):
    '''i_offset = np.random.randint(args.size)
    j_offset = np.random.randint(args.size)'''
    mid = np.int(ml.args.size / 2)
    draw = np.random.multivariate_normal((0,0),((1,0),(0,1)))
    i_offset = min(max(-mid, np.int(draw[0] * mid / 3)), mid)
    j_offset = min(max(-mid, np.int(draw[1] * mid / 3)), mid)
    print(i_offset, j_offset)
    data, label = next(iter(ml.dataset.data_loader))
    print (data.shape)  
    idx = 0
    data_full, label_full, pos_full = couples_gen(data[idx, 0, :, :], label[idx], i_offset, j_offset, size=args.size, contrast=1.)
    label_full = np.array(label_full, dtype = 'double')
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots(1, 4, figsize=((15, 5)))
    #ax[0].imshow(a_data)
    ax[0].imshow(data_full)
    ax[0].set_title('image input')
   
    #mu_output, logvar_output, u_output, 
    z_hat_logit_output = ml.model(torch.from_numpy(data_full[None, None, :, :]), 
                                                                      torch.from_numpy(label_full[None, :]),
                                                                      torch.from_numpy(pos_full[None, :]))
    #ax[2].imshow(F.sigmoid(output[0, 0, :, :]).detach().numpy())
    #plt.title("("+str(i_offset)+","+str(j_offset)+"), label = "+str(label[idx].item()))
    rep = torch.argmax(z_hat_logit_output).detach().numpy()

    #ig, ax = plt.subplots(1, 3, figsize=((13, 5)))
    #ax[0].plot(a_data)
    ax[1].plot(j_offset, i_offset, 'r+', ms = 15)
    ax[1].set_xlim([-128, 128])
    ax[1].set_ylim([128, -128])
    ax[1].xaxis.grid(True)
    ax[1].yaxis.grid(True)
    ax[1].set_title('actual offset')
    
    '''u_offset = u_output.detach().numpy()
    mu_offset = mu_output.detach().numpy()
    logvar_offset = logvar_output.detach().numpy()
    DIM1 = 0
    DIM2 = 1
    axe_x, axe_y = np.mgrid[-4:4:.01, -4:4:.01]
    q = multivariate_normal(mu_offset[0], np.exp(logvar_offset[0]) * np.eye(2))
    pos = np.empty(axe_x.shape + (2,))
    pos[:, :, DIM1] = axe_x; pos[:, :, DIM2] = axe_y

    print(mu_offset, u_offset)
    ax[2].contourf(axe_x, axe_y, q.pdf(pos))
    ax[2].plot(u_offset[0][0], u_offset[0][1], 'r+', ms = 15)
    ax[2].xaxis.grid(True)
    ax[2].set_xlim([-4, 4])
    ax[2].set_ylim([-4, 4])
    ax[2].yaxis.grid(True)
    ax[2].set_title('offset PG encoding')    
    ax[2].axis('equal')'''
    
    
    ax[3].bar(np.arange(10), F.softmax(z_hat_logit_output[0,:]).detach().numpy())
    ax[3].set_ylim([0,1])
    ax[3].set_title("pos = ("+str(i_offset)+","+str(j_offset)+"), label = "+str(label[idx].item())+', rep = '+str(rep))

    plt.show()
# Out:
# -16 -21
# torch.Size([50, 1, 28, 28])
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:70: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# -3 12
# torch.Size([50, 1, 28, 28])
# 15 -13
# torch.Size([50, 1, 28, 28])
# 61 17
# torch.Size([50, 1, 28, 28])
# 34 29
# torch.Size([50, 1, 28, 28])
# -9 0
# torch.Size([50, 1, 28, 28])
# -13 44
# torch.Size([50, 1, 28, 28])
# 12 -5
# torch.Size([50, 1, 28, 28])
# 105 38
# torch.Size([50, 1, 28, 28])
# -3 24
# torch.Size([50, 1, 28, 28])

# %%
_ = plt.plot(data_full)

# %%
size = 256
grid_x, grid_y = np.abs(np.mgrid[-size/2:size/2, -size/2:size/2]) * 8 / size
pos = np.empty((size, size, 2))
pos[:, :, 0] = grid_x; pos[:, :, 1] = grid_y
d = multivariate_normal([0, 0], [[1, 0], [0, 1]])
mask = d.pdf(pos)
mask2 = np.exp(-20 * mask)
_ = plt.imshow(mask2)

# %%
np.random.randn(5)

# %%
output = ml.model(torch.from_numpy(data_full[None, None, :, :]))#.double())
output.shape

# %%
output = torch.from_numpy(data_full[None, None, :, :].astype(np.float))
output.shape

# %%
output = ml.model(torch.from_numpy(data_full[None, None, :, :])).detach().numpy()[0, 0, :, :]
output.shape

# %%
output.min(), output.max()

# %%
_ = plt.plot(a_data)

# %%
draw = np.random.multivariate_normal((0,0),((1,0),(0,1)))

# %%
ml.model.deconv1.bias.detach().numpy()

# %%
plt.plot(ml.model.deconv1.bias.detach().numpy())

# %%
plt.plot((1 + np.tanh(ml.model.fc4.bias.detach().numpy()))/2)

# %%
plt.imshow(np.reshape(ml.model.fc4.bias.detach().numpy(),(64,64)))

# %%
data, foo = next(iter(ml.dataset.data_loader))

# %%
foo

# %%
target_full = np.zeros(10, dtype = 'int')

# %%
target_full

# %%
loss_u = torch.zeros(1)
